# %% [markdown]
# # ASL Training Data Pre-processing

# %% [markdown]
# Hello! In this file, I will pre-process training data that will be used to train a model to interpret ASL characters.

# %% [markdown]
# ## Steps
# 1. Import necessary packages and libraries.
# 2. Extract landmarks from all of the images and create the training DataFrame.
# 3. Apply any transformations (if needed) and perform some minor EDA.
# 4. Save the training Dataframe as a CSV file in the processed_data folder

# %% [markdown]
# I will first import the following packages.
# * MediaPipe - this is a library used to detect hand "landmarks". This is what I will use to extract data from the training images.
# * OpenCV (cv2) - this is a Computer Vision library that I will use to handle images.
# * Pandas - this is a widely used library for handling data. It is very powerful and I will be using it as a result.
# * NumPy - this is a popular library used for handling arrays. In this case, all of the data extracted from the images will be in the form of arrays.
# * MatPlotLib - a popular and easy to use plotting library. I will be using this to initially troubleshoot and ensure that MediaPipe is correctly detecting landmarks.

# %%
import mediapipe as mp
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread(filename="data/raw_data/asl_alphabet_train/asl_alphabet_train/K/K11.jpg") # Reads file in

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# plt.imshow(img_rgb)
# plt.axis('off')  # Hide axes
# plt.show()

mp_drawing = mp.solutions.drawing_utils
mp_hand = mp.solutions.hands
hand = mp_hand.Hands()

result = hand.process(img_rgb)
if result.multi_hand_landmarks:
    for hand_landmarks in result.multi_hand_landmarks:
        print(hand_landmarks)
        mp_drawing.draw_landmarks(img_rgb, hand_landmarks, mp_hand.HAND_CONNECTIONS)
# Out:
# landmark {
#   x: 0.504340708
#   y: 0.925767362
#   z: 1.25715394e-06
# }
# landmark {
#   x: 0.602524757
#   y: 0.859303772
#   z: -0.0823102295
# }
# landmark {
#   x: 0.618494511
#   y: 0.718255281
#   z: -0.109125488
# }
# landmark {
#   x: 0.522621632
#   y: 0.609538436
#   z: -0.129742354
# }
# landmark {
#   x: 0.447108805
#   y: 0.526464224
#   z: -0.146065816
# }
# landmark {
#   x: 0.60772568
#   y: 0.586473346
#   z: -0.040167205
# }
# landmark {
#   x: 0.650381923
#   y: 0.445316523
#   z: -0.0879363418
# }
# landmark {
#   x: 0.671849072
#   y: 0.352281481
#   z: -0.118833132
# }
# landmark {
#   x: 0.686453
#   y: 0.271739095
#   z: -0.137239531
# }
# landmark {
#   x: 0.50768584
#   y: 0.595873237
#   z: -0.035995841
# }
# landmark {
#   x: 0.467882156
#   y: 0.431367815
#   z: -0.106602237
# }
# landmark {
#   x: 0.438350499
#   y: 0.329152137
#   z: -0.152939022
# }
# landmark {
#   x: 0.407817632
#   y: 0.246621
#   z: -0.170578942
# }
# landmark {
#   x: 0.428063065
#   y: 0.647488296
#   z: -0.0404295437
# }
# landmark {
#   x: 0.406222403
#   y: 0.582888603
#   z: -0.155361429
# }
# landmark {
#   x: 0.452061
#   y: 0.692619324
#   z: -0.175204337
# }
# landmark {
#   x: 0.479064882
#   y: 0.764469564
#   z: -0.150813341
# }
# landmark {
#   x: 0.361070275
#   y: 0.718752384
#   z: -0.0478694588
# }
# landmark {
#   x: 0.35804826
#   y: 0.653241277
#   z: -0.146830142
# }
# landmark {
#   x: 0.39724952
#   y: 0.744938672
#   z: -0.147471741
# }
# landmark {
#   x: 0.420150161
#   y: 0.810183167
#   z: -0.120612144
# }
# I0000 00:00:1738477709.032006 9352528 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M1
# W0000 00:00:1738477709.058725 9384012 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1738477709.067341 9384012 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
plt.imshow(img_rgb)
